# %%
import pandas as pd
import scipy.stats as sp
import seaborn as sns

# %%
df = pd.read_excel('BaseDados.xlsx')

# %%
df
# Out:
#                País   id     Ano       GDP PPP       ICE      Gini  \
# 0            Canada  1.0  1995.0  6.881836e+11  0.975289  38.16969
# 1            Canada  1.0  1996.0  7.121309e+11  0.970932  37.94672
# 2            Canada  1.0  1997.0  7.553902e+11  0.928586  38.11684
# 3            Canada  1.0  1998.0  7.936743e+11  0.923304  37.88969
# 4            Canada  1.0  1999.0  8.464129e+11  0.952495  38.13941
# ..              ...  ...     ...           ...       ...       ...
# 142  Estados Unidos  7.0  2011.0  1.559973e+13  1.568274  42.30990
# 143  Estados Unidos  7.0  2012.0  1.625397e+13  1.511340  42.07940
# 144  Estados Unidos  7.0  2013.0  1.684319e+13  1.612058  42.02312
# 145  Estados Unidos  7.0  2014.0  1.755068e+13  1.569578  41.99693
# 146  Estados Unidos  7.0  2015.0  1.820602e+13  1.721982  41.98162
#
#        População
# 0     29302311.0
# 1     29610218.0
# 2     29905948.0
# 3     30155173.0
# 4     30401286.0
# ..           ...
# 142  311583481.0
# ...

# %%
df.describe()
# Out:
#                id          Ano       GDP PPP         ICE        Gini  \
# count  147.000000   147.000000  1.470000e+02  147.000000  147.000000
# mean     4.000000  2005.000000  3.165390e+12    1.616601   38.081215
# std      2.006838     6.076003  4.199818e+12    0.522125    2.443489
# min      1.000000  1995.000000  2.171588e+11    0.574688   31.738510
# 25%      2.000000  2000.000000  1.016718e+12    1.075376   36.666055
# 50%      4.000000  2005.000000  1.621396e+12    1.644969   38.116840
# 75%      6.000000  2010.000000  2.597044e+12    2.040047   39.842005
# max      7.000000  2015.000000  1.820602e+13    2.445310   42.347030
#
#           População
# count  1.470000e+02
# mean   8.346835e+07
# std    8.973396e+07
# min    7.040687e+06
# 25%    3.417211e+07
# 50%    5.975653e+07
# 75%    8.168233e+07
# max    3.207390e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   País       147 non-null    object
#  1   id         147 non-null    float64
#  2   Ano        147 non-null    float64
#  3   GDP PPP    147 non-null    float64
#  4   ICE        147 non-null    float64
#  5   Gini       147 non-null    float64
#  6   População  147 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.2+ KB

# %%
sns.pairplot(df)
